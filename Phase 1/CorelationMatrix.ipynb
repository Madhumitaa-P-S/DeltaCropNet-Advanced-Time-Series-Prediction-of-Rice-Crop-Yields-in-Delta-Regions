# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
weather_dataset=pd.read_csv("C:\\Users\\C KIRANMAYI\\Downloads\\Phase 1\\Phase 1\\csv\\ndvi_with_weather.csv")

# %%
weather_dataset
# Out:
#      Year  Month  Precipitation (mm)  Max Temperature (C)  \
# 0    2000      1            0.000000            30.620000
# 1    2000      2            0.790625            33.623125
# 2    2000      3            0.000000            35.708125
# 3    2000      4            0.000000            39.083750
# 4    2000      5            0.593125            38.268125
# ..    ...    ...                 ...                  ...
# 247  2020      8            3.030625            34.403125
# 248  2020      9            5.336250            33.391875
# 249  2020     10            4.479375            33.220625
# 250  2020     11            8.304375            31.696250
# 251  2020     12            9.293750            28.496250
#
#      Min Temperature (C)  Average Temperature (C)  \
# 0              19.251875                11.368750
# 1              20.310000                13.315000
# 2              20.649375                15.056250
# 3              25.124375                13.960000
# 4              25.467500                12.801250
# ..                   ...                      ...
# 247            24.659375                 9.743125
# 248            24.107500                 9.284375
# 249            23.686875                 9.532500
# 250            22.150625                 9.544375
# 251            20.585625                 7.910625
#
#      Specific Humidity 2m (kg kg-1)  Relative Humidity 2m (%)  \
# 0                         14.910000                 77.135625
# 1                         15.888125                 73.709375
# 2                         15.571875                 67.857500
# 3                         17.315625                 65.190625
# 4                         17.368750                 63.735000
# ..                              ...                       ...
# 247                       18.366875                 74.887500
# 248                       18.158125                 77.657500
# 249                       18.178750                 78.869375
# 250                       18.157500                 83.438125
# 251                       16.801875                 85.510000
#
#      Surface Pressure (K Pa)  Dew Point (C)  Min Wind Speed (m/s)  \
# 0                 100.341875      20.165625              0.790625
# 1                 100.177500      21.145000              0.614375
# 2                 100.088125      20.646875              0.306250
# 3                  99.819375      22.387500              0.395625
# 4                  99.809375      22.468750              0.366875
# ..                       ...            ...                   ...
# 247                99.776250      23.545000              0.372500
# 248                99.833125      23.370000              0.564375
# 249                99.868750      23.411250              0.190000
# 250               100.218750      23.444375              0.504375
# 251               100.310625      22.150625              2.838750
#
#      Max Wind Speed (m/s)  Cloud Coverage      NDVI
# 0                9.227500         0.64000  0.434257
# 1                8.026875         0.65750  0.464668
# 2                7.492500         0.67500  0.458238
# 3                8.481875         0.66000  0.409358
# 4                8.679375         0.67875  0.404442
# ..                    ...             ...       ...
# 247             10.689375         0.65375  0.546573
# 248             10.001250         0.66250  0.554361
# 249              8.945625         0.62750  0.614798
# 250             10.522500         0.65500  0.640854
# 251             10.126250         0.64875  0.642311
#
# [252 rows x 14 columns]

# %%
weather_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Year                            252 non-null    int64
#  1   Month                           252 non-null    int64
#  2   Precipitation (mm)              252 non-null    float64
#  3   Max Temperature (C)             252 non-null    float64
#  4   Min Temperature (C)             252 non-null    float64
#  5   Average Temperature (C)         252 non-null    float64
#  6   Specific Humidity 2m (kg kg-1)  252 non-null    float64
#  7   Relative Humidity 2m (%)        252 non-null    float64
#  8   Surface Pressure (K Pa)         252 non-null    float64
#  9   Dew Point (C)                   252 non-null    float64
#  10  Min Wind Speed (m/s)            252 non-null    float64
#  11  Max Wind Speed (m/s)            252 non-null    float64
#  12  Cloud Coverage                  252 non-null    float64
#  13  NDVI                            252 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 27.7 KB

# %% [markdown]
# ### Creating a Correlation Matrix

# %%
#Creating the correlation matrix for the features
corr_matrix=weather_dataset.corr()
corr_matrix
# Out:
#                                         Year         Month  \
# Year                            1.000000e+00  5.055640e-15
# Month                           5.055640e-15  1.000000e+00
# Precipitation (mm)              3.337927e-02  6.040293e-01
# Max Temperature (C)             1.040358e-02 -3.122235e-01
# Min Temperature (C)             8.199847e-02  7.867465e-02
# Average Temperature (C)        -9.925618e-02 -6.488504e-01
# Specific Humidity 2m (kg kg-1)  6.085022e-02  4.712985e-01
# Relative Humidity 2m (%)       -3.153786e-02  5.027013e-01
# Surface Pressure (K Pa)         6.125528e-02 -1.896441e-01
# Dew Point (C)                   5.747229e-02  5.085550e-01
# Min Wind Speed (m/s)           -2.887264e-02 -5.700138e-02
# Max Wind Speed (m/s)           -4.961015e-02  3.412777e-01
# Cloud Coverage                 -2.041110e-01 -5.581317e-01
# NDVI                            1.377474e-01  4.714733e-01
#
#                                 Precipitation (mm)  Max Temperature (C)  \
# Year                                      0.033379             0.010404
# Month                                     0.604029            -0.312224
# Precipitation (mm)                        1.000000            -0.380541
# Max Temperature (C)                      -0.380541             1.000000
# Min Temperature (C)                      -0.057538             0.813396
# Average Temperature (C)                  -0.571693             0.557011
# Specific Humidity 2m (kg kg-1)            0.459096             0.354430
# Relative Humidity 2m (%)                  0.676524            -0.854654
# Surface Pressure (K Pa)                   0.002425            -0.694719
# Dew Point (C)                             0.485846             0.299594
# Min Wind Speed (m/s)                     -0.181703            -0.368400
# Max Wind Speed (m/s)                      0.175094             0.100827
# Cloud Coverage                           -0.290443             0.115521
# NDVI                                      0.443207            -0.788973
#
#                                 Min Temperature (C)  Average Temperature (C)  \
# Year                                       0.081998                -0.099256
# Month                                      0.078675                -0.648850
# Precipitation (mm)                        -0.057538                -0.571693
# Max Temperature (C)                        0.813396                 0.557011
# Min Temperature (C)                        1.000000                -0.030042
# Average Temperature (C)                   -0.030042                 1.000000
# Specific Humidity 2m (kg kg-1)             0.726256                -0.427855
# Relative Humidity 2m (%)                  -0.563964                -0.663375
# Surface Pressure (K Pa)                   -0.860206                 0.034354
# Dew Point (C)                              0.695111                -0.477611
# Min Wind Speed (m/s)                      -0.307198                -0.194484
# Max Wind Speed (m/s)                       0.264984                -0.205035
# Cloud Coverage                            -0.223519                 0.517647
# NDVI                                      -0.576782                -0.532217
#
#                                 Specific Humidity 2m (kg kg-1)  \
# Year                                                  0.060850
# Month                                                 0.471298
# Precipitation (mm)                                    0.459096
# Max Temperature (C)                                   0.354430
# Min Temperature (C)                                   0.726256
# Average Temperature (C)                              -0.427855
# Specific Humidity 2m (kg kg-1)                        1.000000
# Relative Humidity 2m (%)                              0.104227
# Surface Pressure (K Pa)                              -0.687514
# Dew Point (C)                                         0.997103
# Min Wind Speed (m/s)                                 -0.346364
# Max Wind Speed (m/s)                                  0.238632
# Cloud Coverage                                       -0.429024
# NDVI                                                 -0.073144
#
#                                 Relative Humidity 2m (%)  \
# Year                                           -0.031538
# Month                                           0.502701
# Precipitation (mm)                              0.676524
# Max Temperature (C)                            -0.854654
# Min Temperature (C)                            -0.563964
# Average Temperature (C)                        -0.663375
# Specific Humidity 2m (kg kg-1)                  0.104227
# Relative Humidity 2m (%)                        1.000000
# Surface Pressure (K Pa)                         0.462330
# Dew Point (C)                                   0.156594
# Min Wind Speed (m/s)                            0.120231
# Max Wind Speed (m/s)                           -0.064824
# Cloud Coverage                                 -0.238396
# NDVI                                            0.796854
#
#                                 Surface Pressure (K Pa)  Dew Point (C)  \
# Year                                           0.061255       0.057472
# Month                                         -0.189644       0.508555
# Precipitation (mm)                             0.002425       0.485846
# Max Temperature (C)                           -0.694719       0.299594
# Min Temperature (C)                           -0.860206       0.695111
# Average Temperature (C)                        0.034354      -0.477611
# Specific Humidity 2m (kg kg-1)                -0.687514       0.997103
# Relative Humidity 2m (%)                       0.462330       0.156594
# Surface Pressure (K Pa)                        1.000000      -0.662107
# Dew Point (C)                                 -0.662107       1.000000
# Min Wind Speed (m/s)                           0.323287      -0.323411
# Max Wind Speed (m/s)                          -0.449832       0.245189
# Cloud Coverage                                 0.325691      -0.452981
# NDVI                                           0.440238      -0.024440
#
#                                 Min Wind Speed (m/s)  Max Wind Speed (m/s)  \
# Year                                       -0.028873             -0.049610
# Month                                      -0.057001              0.341278
# Precipitation (mm)                         -0.181703              0.175094
# Max Temperature (C)                        -0.368400              0.100827
# Min Temperature (C)                        -0.307198              0.264984
# Average Temperature (C)                    -0.194484             -0.205035
# Specific Humidity 2m (kg kg-1)             -0.346364              0.238632
# Relative Humidity 2m (%)                    0.120231             -0.064824
# Surface Pressure (K Pa)                     0.323287             -0.449832
# Dew Point (C)                              -0.323411              0.245189
# Min Wind Speed (m/s)                        1.000000              0.128905
# Max Wind Speed (m/s)                        0.128905              1.000000
# Cloud Coverage                             -0.059544             -0.412660
# NDVI                                        0.193535             -0.010384
#
#                                 Cloud Coverage      NDVI
# Year                                 -0.204111  0.137747
# Month                                -0.558132  0.471473
# Precipitation (mm)                   -0.290443  0.443207
# Max Temperature (C)                   0.115521 -0.788973
# Min Temperature (C)                  -0.223519 -0.576782
# Average Temperature (C)               0.517647 -0.532217
# Specific Humidity 2m (kg kg-1)       -0.429024 -0.073144
# Relative Humidity 2m (%)             -0.238396  0.796854
# Surface Pressure (K Pa)               0.325691  0.440238
# Dew Point (C)                        -0.452981 -0.024440
# Min Wind Speed (m/s)                 -0.059544  0.193535
# Max Wind Speed (m/s)                 -0.412660 -0.010384
# Cloud Coverage                        1.000000 -0.303053
# NDVI                                 -0.303053  1.000000

# %%
mask = np.zeros_like(corr_matrix, dtype=np.bool_)
mask[np.triu_indices_from(mask)]= True

# %%
f, ax = plt.subplots(figsize=(12, 10)) 
heatmap = sns.heatmap(corr_matrix, mask = mask,square = True,linewidths = .5, cmap = 'coolwarm', cbar_kws = {'shrink': .4, 'ticks' : [-1, -.5, 0, 0.5, 1]},vmin = -1, vmax = 1,annot = True,annot_kws = {'size': 12})
#add the column names as labels
ax.set_yticklabels(corr_matrix.columns, rotation = 0)
ax.set_xticklabels(corr_matrix.columns)
sns.set_style({'xtick.bottom': True}, {'ytick.left': True})
# Out:
# c:\Users\C KIRANMAYI\anaconda3\envs\myenv\lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %% [markdown]
# (Precipitation,Min Temperature,Specific Humidity,Relative Humidity,Dew Point,Min Wind Speed,Max Wind Speed)
# (Max Temperature,Min Temperature,Average Temperature,Cloud Coverage)
# (Min Temperature,Specific Humidity,Relative Humidity,Dew Point,Min Wind Speed,Max Wind Speed)
# (Average Temperature,surface Pressure,cloud Coverage)
# (Specific Humidity,Relative Humidity,Dew Point,Min Wind Speed,Max Wind Speed)
# (Relative Humidity,Dew Point,Min Wind Speed,Max Wind Speed)
# (Dew point,Min Wind Speed,Max Wind Speed)
# Almost everything is related
